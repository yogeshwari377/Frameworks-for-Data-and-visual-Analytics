# %%
import pandas as pd
import numpy as np

data = {
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'Married': ['Yes', 'No', 'Yes', 'Yes', 'No'],
    'Dependents': ['0', '1', '3+', '2', '0'],
    'Education': ['Graduate', 'Graduate', 'Not Graduate', 'Graduate', 'Graduate'],
    'Self_Employed': ['No', 'Yes', 'No', 'No', 'Yes'],
    'Property_Area': ['Urban', 'Rural', 'Semiurban', 'Urban', 'Rural'],
    'ApplicantIncome': [5000, 3000, 7000, 4500, 6000],
    'CoapplicantIncome': [1000, 1500, 0, 1200, 800],
    'LoanAmount': [150, 100, 200, 120, 180]
}

df = pd.DataFrame(data)

print("Dataset Created Successfully")
df.head()
# Out:
# Dataset Created Successfully
#    Gender Married Dependents     Education Self_Employed Property_Area  \
# 0    Male     Yes          0      Graduate            No         Urban
# 1  Female      No          1      Graduate           Yes         Rural
# 2    Male     Yes         3+  Not Graduate            No     Semiurban
# 3  Female     Yes          2      Graduate            No         Urban
# 4    Male      No          0      Graduate           Yes         Rural
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount
# 0             5000               1000         150
# 1             3000               1500         100
# 2             7000                  0         200
# 3             4500               1200         120
# 4             6000                800         180

# %%
print("First 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())

print("\nDataset Information:")
print(df.info())

print("\nDescriptive Statistics:")
print(df.describe())

print("\nColumn Names:")
print(df.columns)
# Out:
# First 5 rows:
#    Gender Married Dependents     Education Self_Employed Property_Area  \
# 0    Male     Yes          0      Graduate            No         Urban
# 1  Female      No          1      Graduate           Yes         Rural
# 2    Male     Yes         3+  Not Graduate            No     Semiurban
# 3  Female     Yes          2      Graduate            No         Urban
# 4    Male      No          0      Graduate           Yes         Rural
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount
# 0             5000               1000         150
# 1             3000               1500         100
# 2             7000                  0         200
# 3             4500               1200         120
# 4             6000                800         180
#
# Last 5 rows:
#    Gender Married Dependents     Education Self_Employed Property_Area  \
# 0    Male     Yes          0      Graduate            No         Urban
# ...

# %%
categorical_cols = [
    'Gender',
    'Married',
    'Dependents',
    'Education',
    'Self_Employed',
    'Property_Area'
]

for col in categorical_cols:
    print(f"\nUnique values in '{col}':")
    print(df[col].unique())
# Out:
# Unique values in 'Gender':
# ['Male' 'Female']
#
# Unique values in 'Married':
# ['Yes' 'No']
#
# Unique values in 'Dependents':
# ['0' '1' '3+' '2']
#
# Unique values in 'Education':
# ['Graduate' 'Not Graduate']
#
# Unique values in 'Self_Employed':
# ['No' 'Yes']
#
# Unique values in 'Property_Area':
# ['Urban' 'Rural' 'Semiurban']

# %%
df['Dependents'] = df['Dependents'].replace('3+', 3)

df['Dependents'] = pd.to_numeric(
    df['Dependents'],
    errors='coerce'
).astype('Int64')

print("Value counts in Dependents:")
print(df['Dependents'].value_counts(dropna=False))
# Out:
# Value counts in Dependents:
# Dependents
# 0    2
# 1    1
# 3    1
# 2    1
# Name: count, dtype: Int64

# %%
cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

for col in cols:
    print(f"\nStatistics for '{col}':")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Mode: {df[col].mode().values}")
    print(f"Range: {df[col].max() - df[col].min():.2f}")
    print(f"Variance: {df[col].var():.2f}")
    print(f"Standard Deviation: {df[col].std():.2f}")
# Out:
# Statistics for 'ApplicantIncome':
# Mean: 5100.00
# Median: 5000.00
# Mode: [3000 4500 5000 6000 7000]
# Range: 4000.00
# Variance: 2300000.00
# Standard Deviation: 1516.58
#
# Statistics for 'CoapplicantIncome':
# Mean: 900.00
# Median: 1000.00
# Mode: [   0  800 1000 1200 1500]
# Range: 1500.00
# Variance: 320000.00
# Standard Deviation: 565.69
#
# Statistics for 'LoanAmount':
# Mean: 150.00
# Median: 150.00
# Mode: [100 120 150 180 200]
# Range: 100.00
# Variance: 1700.00
# Standard Deviation: 41.23
